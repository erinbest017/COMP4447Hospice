# %%
import requests
import pandas as pd

# API base URL and parameters
api_url = "https://npiregistry.cms.hhs.gov/api/"
params = {
    "version": "2.1",
    "enumeration_type": "NPI-2",
    "state": "CO",
    "taxonomy_description": "hospice",
    "limit": 200,  # max allowed per call
    "skip": 0
}

all_results = []

while True:
    response = requests.get(api_url, params=params)
    if response.status_code != 200:
        print(f"Error: {response.status_code}")
        break
    
    data = response.json()
    results = data.get("results", [])
    
    if not results:
        break
    
    for entry in results:
        npi = entry.get("number", "")
        basic = entry.get("basic", {})
        name = basic.get("organization_name", "")
        status = basic.get("status", "")
        
        # Practice locations can be multiple; take the first one
        addresses = entry.get("addresses", [])
        practice_address = next((addr for addr in addresses if addr.get("address_purpose") == "LOCATION"), {})
        full_address = f"{practice_address.get('address_1', '')} {practice_address.get('city', '')}, {practice_address.get('state', '')} {practice_address.get('postal_code', '')}"
        
        # Get taxonomy entries
        taxonomies = entry.get("taxonomies", [])
        taxonomy_entries = [(t.get("desc", ""), t.get("primary")) for t in taxonomies]
        
        # Get issuer list
        identifiers = entry.get("identifiers", [])
        issuers = [iden.get("issuer", "") for iden in identifiers if iden.get("issuer")]

        all_results.append({
            "NPI": npi,
            "Name": name,
            "Status": status,
            "Primary Practice Address": full_address,
            "Taxonomy Entries": taxonomy_entries,
            "Issuers": issuers
        })

    # Pagination: skip next batch
    params["skip"] += 200
    if len(results) < 200:
        break  # Stop if fewer than 200 returned (i.e., last page)

# Convert to DataFrame
df = pd.DataFrame(all_results)

# %%
df.to_csv("hospice_organizations_CO.csv", index=False)

# %%
df
# Out:
#             NPI                                   Name Status  \
# 0    1760093470               247 HOME HEALTH CARE LTD      A
# 1    1740072065          A BETTER COLORADO HOSPICE LLC      A
# 2    1003483330        A PEACEFUL JOURNEY HOSPICE, LLC      A
# 3    1861097982         ABODE HEALTHCARE COLORADO, INC      A
# 4    1326459025         ABODE HEALTHCARE COLORADO, INC      A
# ..          ...                                    ...    ...
# 297  1194839001                WYOMING HOME HEALTH INC      A
# 298  1013648583                        YNA HOSPICE INC      A
# 299  1285645382                    YULIYA GOSTISHCHEVA      A
# 300  1942931415                         ZA HOSPICE INC      A
# 301  1477372571  ZION SELAH HOME HEALTHCARE AGENCY LLC      A
#
#                               Primary Practice Address  \
# 0        8055 E TUFTS AVE STE 250 DENVER, CO 802372857
# 1              126 W D ST STE 200 PUEBLO, CO 810034430
# 2       2851 S PARKER RD STE 1130 AURORA, CO 800142732
# 3            1050 EAGLERIDGE BLVD PUEBLO, CO 810082130
# 4    5465 MARK DABLING BLVD COLORADO SPRINGS, CO 80...
# ..                                                 ...
# 297   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
# 298  3190 S VAUGHN WAY STE 550 OFF 520 AURORA, CO 8...
# 299              1240 S PARKER RD DENVER, CO 802317558
# 300  102 S TEJON ST STE 1100 OFF 1111 COLORADO SPRI...
# 301   2821 S PARKER RD STE 2-1017 AURORA, CO 800142735
#
#                                       Taxonomy Entries Issuers
# 0              [(Hospice Care, Community Based, True)]      []
# 1              [(Hospice Care, Community Based, True)]      []
# 2              [(Hospice Care, Community Based, True)]      []
# 3              [(Hospice Care, Community Based, True)]      []
# 4              [(Hospice Care, Community Based, True)]      []
# ..                                                 ...     ...
# 297  [(Case Management, False), (Day Training, Deve...      []
# 298            [(Hospice Care, Community Based, True)]      []
# 299            [(Hospice Care, Community Based, True)]      []
# 300            [(Hospice Care, Community Based, True)]      []
# 301  [(Home Health, True), (Hospice Care, Community...      []
#
# [302 rows x 6 columns]

# %%
# ZIP9 (may have zip9 or zip5)
df["ZIP9"] = df["Primary Practice Address"].str.extract(r'(\d{5}(?:-\d{4})?)$')

# %%
# 5 digit zip (ZIP5)
df['ZIP5'] = df['ZIP9'].str[:5]

df['ZIP5']
# Out:
# 0      72857
# 1      34430
# 2      42732
# 3      82130
# 4      83842
#        ...
# 297    85557
# 298    80014
# 299    17558
# 300    80903
# 301    42735
# Name: ZIP5, Length: 302, dtype: object

# %%
# Hospice facilities status - all Active
df["Status"].value_counts()
# Out:
# Status
# A    302
# Name: count, dtype: int64

# %%
# Are there any duplicate NPIs? - NO
df[df["NPI"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [NPI, Name, Status, Primary Practice Address, Taxonomy Entries, Issuers, ZIP9, ZIP5]
# Index: []

# %%
# Are there any duplicate Names? YES 117 are duplicate names
df[df["Name"].duplicated(keep=False)]
# Out:
#             NPI                              Name Status  \
# 3    1861097982    ABODE HEALTHCARE COLORADO, INC      A
# 4    1326459025    ABODE HEALTHCARE COLORADO, INC      A
# 5    1447611512   ABODE HEALTHCARE COLORADO, INC.      A
# 6    1760169221   ABODE HEALTHCARE COLORADO, INC.      A
# 7    1275919029   ABODE HEALTHCARE COLORADO, INC.      A
# ..          ...                               ...    ...
# 283  1689365033  VALLEY VIEW HOSPITAL ASSOCIATION      A
# 290  1811753023                 WELLNESS PLUG LLC      A
# 291  1699592584                 WELLNESS PLUG LLC      A
# 296  1346699725           WYOMING HOME HEALTH INC      A
# 297  1194839001           WYOMING HOME HEALTH INC      A
#
#                               Primary Practice Address  \
# 3            1050 EAGLERIDGE BLVD PUEBLO, CO 810082130
# 4    5465 MARK DABLING BLVD COLORADO SPRINGS, CO 80...
# 5    744 HORIZON CT STE 110 GRAND JUNCTION, CO 8150...
# 6         200 E 7TH ST STE 200B LOVELAND, CO 805374864
# 7        445 UNION BLVD STE 223 LAKEWOOD, CO 802281241
# ..                                                 ...
# 283  1830 BLAKE AVE STE 202 GLENWOOD SPRINGS, CO 81...
# 290     1562 S PARKER RD STE 320C DENVER, CO 802312721
# 291     1562 S PARKER RD STE 320C DENVER, CO 802312721
# 296   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
# 297   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
#
#                                       Taxonomy Entries  \
# 3              [(Hospice Care, Community Based, True)]
# 4              [(Hospice Care, Community Based, True)]
# 5              [(Hospice Care, Community Based, True)]
# 6              [(Hospice Care, Community Based, True)]
# 7              [(Hospice Care, Community Based, True)]
# ..                                                 ...
# 283  [(Internal Medicine, Hospice and Palliative Me...
# 290            [(Hospice Care, Community Based, True)]
# 291  [(Home Health, True), (Hospice Care, Community...
# 296  [(Case Management, False), (Home Health, False...
# 297  [(Case Management, False), (Day Training, Deve...
#
#                                                Issuers   ZIP9   ZIP5
# 3                                                   []  82130  82130
# 4                                                   []  83842  83842
# 5                                                   []  63915  63915
# 6                                                   []  74864  74864
# 7                                                   []  81241  81241
# ..                                                 ...    ...    ...
# 283                                                 []  14261  14261
# 290                                                 []  12721  12721
# 291  [Colorado Department of Public Health and Envi...  12721  12721
# 296                                                 []  85557  85557
# 297                                                 []  85557  85557
#
# [117 rows x 8 columns]

# %%
# Are there any duplicate Names AND Address? YES - 39
df[df.duplicated(subset=["Name", "Primary Practice Address"], keep=False)]
# Out:
#             NPI                                         Name Status  \
# 7    1275919029              ABODE HEALTHCARE COLORADO, INC.      A
# 8    1427469113              ABODE HEALTHCARE COLORADO, INC.      A
# 45   1861205908                                BANNER HEALTH      A
# 46   1407409964                                BANNER HEALTH      A
# 62   1639280548         CATHOLIC HEALTH INITIATIVES COLORADO      A
# 64   1457731929         CATHOLIC HEALTH INITIATIVES COLORADO      A
# 79   1326043019          COLORADO VISITING NURSE ASSOCIATION      A
# 80   1861004228          COLORADO VISITING NURSE ASSOCIATION      A
# 118  1851990980                                     HOPEWEST      A
# 119  1326646886                                     HOPEWEST      A
# 121  1437749389                                     HOPEWEST      A
# 122  1942892468                                     HOPEWEST      A
# 123  1811595374                                     HOPEWEST      A
# 124  1043800816                                     HOPEWEST      A
# 131  1093421141                 HOSPICE OF METRO DENVER, INC      A
# 132  1083394332                 HOSPICE OF METRO DENVER, INC      A
# 134  1184491474                 HOSPICE OF METRO DENVER, INC      A
# 135  1023798717                 HOSPICE OF METRO DENVER, INC      A
# 136  1003831835                 HOSPICE OF METRO DENVER, INC      A
# 163  1942554670      LIFE CHOICE HOSPICE OF COLORADO II, LLC      A
# 165  1174041214      LIFE CHOICE HOSPICE OF COLORADO II, LLC      A
# 166  1932642683      LIFE CHOICE HOSPICE OF COLORADO II, LLC      A
# 167  1336493063         LIFE CHOICE HOSPICE OF COLORADO, LLC      A
# 169  1881138287         LIFE CHOICE HOSPICE OF COLORADO, LLC      A
# 183  1962920207                    MOUNT EVANS HOSPICE, INC.      A
# 184  1346284965                    MOUNT EVANS HOSPICE, INC.      A
# 210  1528762713                             PATHWAYS HOSPICE      A
# 212  1558077511                             PATHWAYS HOSPICE      A
# 213  1275748931                             PATHWAYS HOSPICE      A
# 214  1447027123                             PATHWAYS HOSPICE      A
# 215  1063444305                             PATHWAYS HOSPICE      A
# 216  1467221655                             PATHWAYS HOSPICE      A
# 218  1437997152                             PATHWAYS HOSPICE      A
# 222  1336821396  PIKES PEAK HOSPICE AND PALLIATIVE CARE, INC      A
# 223  1497523104  PIKES PEAK HOSPICE AND PALLIATIVE CARE, INC      A
# 290  1811753023                            WELLNESS PLUG LLC      A
# 291  1699592584                            WELLNESS PLUG LLC      A
# 296  1346699725                      WYOMING HOME HEALTH INC      A
# 297  1194839001                      WYOMING HOME HEALTH INC      A
#
#                               Primary Practice Address  \
# 7        445 UNION BLVD STE 223 LAKEWOOD, CO 802281241
# 8        445 UNION BLVD STE 223 LAKEWOOD, CO 802281241
# 45         2001 70TH AVE STE 100 GREELEY, CO 806344628
# 46         2001 70TH AVE STE 100 GREELEY, CO 806344628
# 62         9100 E MINERAL CIR CENTENNIAL, CO 801123401
# 64         9100 E MINERAL CIR CENTENNIAL, CO 801123401
# 79                6750 W 52ND AVE ARVADA, CO 800023928
# 80                6750 W 52ND AVE ARVADA, CO 800023928
# 118  3090 N 12TH ST UNIT B GRAND JUNCTION, CO 81506...
# 119                195 STAFFORD LN DELTA, CO 814162229
# 121                195 STAFFORD LN DELTA, CO 814162229
# 122                725 S 4TH ST MONTROSE, CO 814014222
# 123                725 S 4TH ST MONTROSE, CO 814014222
# 124  3090 N 12TH ST UNIT B GRAND JUNCTION, CO 81506...
# 131             8289 E LOWRY BLVD DENVER, CO 802307256
# 132             8299 E LOWRY BLVD DENVER, CO 802307256
# 134             8299 E LOWRY BLVD DENVER, CO 802307256
# 135             8289 E LOWRY BLVD DENVER, CO 802307256
# 136             8289 E LOWRY BLVD DENVER, CO 802307256
# 163  5475 TECH CENTER DR STE 105 COLORADO SPRINGS, ...
# 165  5475 TECH CENTER DR STE 105 COLORADO SPRINGS, ...
# 166  5475 TECH CENTER DR STE 105 COLORADO SPRINGS, ...
# 167        4704 HARLAN ST STE 550 DENVER, CO 802127464
# 169        4704 HARLAN ST STE 550 DENVER, CO 802127464
# 183        3081 BERGEN PEAK DR EVERGREEN, CO 804392200
# 184        3081 BERGEN PEAK DR EVERGREEN, CO 804392200
# 210        305 CARPENTER RD FORT COLLINS, CO 805254248
# 212        305 CARPENTER RD FORT COLLINS, CO 805254248
# 213        305 CARPENTER RD FORT COLLINS, CO 805254248
# 214        305 CARPENTER RD FORT COLLINS, CO 805254248
# 215        305 CARPENTER RD FORT COLLINS, CO 805254248
# 216        305 CARPENTER RD FORT COLLINS, CO 805254248
# 218        305 CARPENTER RD FORT COLLINS, CO 805254248
# 222  2550 TENDERFOOT HILL ST COLORADO SPRINGS, CO 8...
# 223  2550 TENDERFOOT HILL ST COLORADO SPRINGS, CO 8...
# 290     1562 S PARKER RD STE 320C DENVER, CO 802312721
# 291     1562 S PARKER RD STE 320C DENVER, CO 802312721
# 296   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
# 297   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
#
#                                       Taxonomy Entries  \
# 7              [(Hospice Care, Community Based, True)]
# 8              [(Hospice Care, Community Based, True)]
# 45             [(Hospice Care, Community Based, True)]
# 46             [(Hospice Care, Community Based, True)]
# 62             [(Hospice Care, Community Based, True)]
# 64   [(Internal Medicine, Hospice and Palliative Me...
# 79             [(Hospice Care, Community Based, True)]
# 80   [(Family Medicine, Hospice and Palliative Medi...
# 118  [(Family Medicine, Hospice and Palliative Medi...
# 119  [(Family Medicine, Hospice and Palliative Medi...
# 121  [(Family Medicine, Hospice and Palliative Medi...
# 122  [(Family Medicine, True), (Family Medicine, Ho...
# 123  [(Family Medicine, Hospice and Palliative Medi...
# 124  [(Family Medicine, False), (Family Medicine, H...
# 131  [(Pediatrics, Hospice and Palliative Medicine,...
# 132  [(Pediatrics, Pediatric Critical Care Medicine...
# 134  [(Emergency Medicine, Hospice and Palliative M...
# 135  [(Family Medicine, Hospice and Palliative Medi...
# 136            [(Hospice Care, Community Based, True)]
# 163            [(Hospice Care, Community Based, True)]
# 165  [(Internal Medicine, Hospice and Palliative Me...
# 166            [(Hospice Care, Community Based, True)]
# 167            [(Hospice Care, Community Based, True)]
# 169  [(Family Medicine, Hospice and Palliative Medi...
# 183  [(Family Medicine, Hospice and Palliative Medi...
# 184            [(Hospice Care, Community Based, True)]
# 210  [(Nurse Practitioner, Adult Health, False), (N...
# 212  [(Pediatrics, Hospice and Palliative Medicine,...
# 213  [(Counselor, Professional, False), (Internal M...
# 214  [(Nurse Practitioner, Adult Health, False), (N...
# 215  [(Social Worker, Clinical, False), (Internal M...
# 216  [(Nurse Practitioner, Adult Health, False), (N...
# 218  [(Emergency Medicine, Hospice and Palliative M...
# 222  [(Family Medicine, Hospice and Palliative Medi...
# 223  [(Physical Medicine & Rehabilitation, Hospice ...
# 290            [(Hospice Care, Community Based, True)]
# 291  [(Home Health, True), (Hospice Care, Community...
# 296  [(Case Management, False), (Home Health, False...
# 297  [(Case Management, False), (Day Training, Deve...
#
#                                                Issuers   ZIP9   ZIP5
# 7                                                   []  81241  81241
# 8                                                   []  81241  81241
# 45                                                  []  44628  44628
# 46                                                  []  44628  44628
# 62                                                  []  23401  23401
# 64                                                  []  23401  23401
# 79                                                  []  23928  23928
# 80                                                  []  23928  23928
# 118                                                 []  62804  62804
# 119                                                 []  62229  62229
# 121                                                 []  62229  62229
# 122                                                 []  14222  14222
# 123                                                 []  14222  14222
# 124                                                 []  62804  62804
# 131                                                 []  07256  07256
# 132                                                 []  07256  07256
# 134                                                 []  07256  07256
# 135                                                 []  07256  07256
# 136                                                 []  07256  07256
# 163                                                 []  92336  92336
# 165                                                 []  92336  92336
# 166                                                 []  92336  92336
# 167                                                 []  27464  27464
# 169                                                 []  27464  27464
# 183                                                 []  92200  92200
# 184                                                 []  92200  92200
# 210                                                 []  54248  54248
# 212                                                 []  54248  54248
# 213                                                 []  54248  54248
# 214                                                 []  54248  54248
# 215  [Aetna, Anthem BCBS - Federal, CIGNA HealthCar...  54248  54248
# 216                                                 []  54248  54248
# 218                                                 []  54248  54248
# 222                                                 []  63998  63998
# 223                                                 []  63998  63998
# 290                                                 []  12721  12721
# 291  [Colorado Department of Public Health and Envi...  12721  12721
# 296                                                 []  85557  85557
# 297                                                 []  85557  85557

# %%
def contains_hospice(entry_list):
    for entry in entry_list:
        for field in entry:
            if isinstance(field, str) and "hospice" in field.lower():
                return True
    return False

# Apply the function
has_hospice = df["Taxonomy Entries"].apply(contains_hospice)

# Summary
print("Total NPIs:", len(df))
print("NPIs with at least one 'Hospice' taxonomy:", has_hospice.sum())

if has_hospice.all():
    print("All NPIs have at least one taxonomy with 'Hospice'.")
else:
    print("Some NPIs are missing a 'Hospice' taxonomy.")
    display(df[~has_hospice][["NPI", "Name", "Taxonomy Entries"]])
# Out:
# Total NPIs: 302
# NPIs with at least one 'Hospice' taxonomy: 302
# All NPIs have at least one taxonomy with 'Hospice'.

# %%
# removing duplicates by name and Primary Care Address
df = df.drop_duplicates(subset=["Name", "Primary Practice Address"], keep="first")

# %%
df #279 total
# Out:
#             NPI                                   Name Status  \
# 0    1760093470               247 HOME HEALTH CARE LTD      A
# 1    1740072065          A BETTER COLORADO HOSPICE LLC      A
# 2    1003483330        A PEACEFUL JOURNEY HOSPICE, LLC      A
# 3    1861097982         ABODE HEALTHCARE COLORADO, INC      A
# 4    1326459025         ABODE HEALTHCARE COLORADO, INC      A
# ..          ...                                    ...    ...
# 296  1346699725                WYOMING HOME HEALTH INC      A
# 298  1013648583                        YNA HOSPICE INC      A
# 299  1285645382                    YULIYA GOSTISHCHEVA      A
# 300  1942931415                         ZA HOSPICE INC      A
# 301  1477372571  ZION SELAH HOME HEALTHCARE AGENCY LLC      A
#
#                               Primary Practice Address  \
# 0        8055 E TUFTS AVE STE 250 DENVER, CO 802372857
# 1              126 W D ST STE 200 PUEBLO, CO 810034430
# 2       2851 S PARKER RD STE 1130 AURORA, CO 800142732
# 3            1050 EAGLERIDGE BLVD PUEBLO, CO 810082130
# 4    5465 MARK DABLING BLVD COLORADO SPRINGS, CO 80...
# ..                                                 ...
# 296   1103 E BOXELDER RD STE JB GILLETTE, WY 827185557
# 298  3190 S VAUGHN WAY STE 550 OFF 520 AURORA, CO 8...
# 299              1240 S PARKER RD DENVER, CO 802317558
# 300  102 S TEJON ST STE 1100 OFF 1111 COLORADO SPRI...
# 301   2821 S PARKER RD STE 2-1017 AURORA, CO 800142735
#
#                                       Taxonomy Entries Issuers   ZIP9   ZIP5
# 0              [(Hospice Care, Community Based, True)]      []  72857  72857
# 1              [(Hospice Care, Community Based, True)]      []  34430  34430
# 2              [(Hospice Care, Community Based, True)]      []  42732  42732
# 3              [(Hospice Care, Community Based, True)]      []  82130  82130
# 4              [(Hospice Care, Community Based, True)]      []  83842  83842
# ..                                                 ...     ...    ...    ...
# 296  [(Case Management, False), (Home Health, False...      []  85557  85557
# 298            [(Hospice Care, Community Based, True)]      []  80014  80014
# 299            [(Hospice Care, Community Based, True)]      []  17558  17558
# 300            [(Hospice Care, Community Based, True)]      []  80903  80903
# 301  [(Home Health, True), (Hospice Care, Community...      []  42735  42735
#
# [279 rows x 8 columns]

# %%
df["Issuers"].value_counts()
# Out:
# Issuers
# []                                                                 266
# [NPI, LICENSE]                                                       1
# [State ID]                                                           1
# [State of Colorado Department of Public Health and Environment]      1
# [License Number]                                                     1
# [Nebraska State Licensure]                                           1
# [State Hospice Licensure]                                            1
# [CO State License Number]                                            1
# [Colorado license]                                                   1
# [License]                                                            1
# [Provider Number]                                                    1
# [MEDICARE]                                                           1
# [BCBS, HMO of CO, Medicare B]                                        1
# [Colorado State License]                                             1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 279 entries, 0 to 301
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NPI                       279 non-null    object
#  1   Name                      279 non-null    object
#  2   Status                    279 non-null    object
#  3   Primary Practice Address  279 non-null    object
#  4   Taxonomy Entries          279 non-null    object
#  5   Issuers                   279 non-null    object
#  6   ZIP9                      279 non-null    object
#  7   ZIP5                      279 non-null    object
# dtypes: object(8)
# memory usage: 19.6+ KB

# %%
df.to_pickle('df.pkl')
